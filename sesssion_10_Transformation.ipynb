# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


file_path=r"C:\Users\purna\Documents\Naresh IT\assignments_ds\Visadataset.csv"
visa_df=pd.read_csv(file_path)
visa_df
cat_cols=visa_df.select_dtypes(include='object').columns
num_cols=visa_df.select_dtypes(exclude='object').columns
num_cols,cat_cols
# Out:
# (Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object'),
#  Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#         'requires_job_training', 'region_of_employment', 'unit_of_wage',
#         'full_time_position', 'case_status'],
#        dtype='object'))

# %% [markdown]
# - generally data has 3 types
#     - positive skew
#     - negative skew
#     - no skew
# - skew nesss happend beacuse of outliers
# - eventhough we treat the outliers still we can see some skew
# - and we know that all the math develpoed by make an assumption as DATA follows Normal disrtibution
# - so tranformation methods ussed to convert data to Normal
# - the important Trandformations are
#     - Log Transformation
#     - Reciprocal Transformation
#     - Sqrt Transformation
#     - Exponential Transformation
#     - Power Transfromation

# %% [markdown]
# **step-1**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Step-2**: read exponential data

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([1.45871646, 0.43660188, 1.90175584, ..., 0.18396881, 0.08383648,
#        0.05086772])

# %% [markdown]
# **step-3**:plot histgoram

# %%
plt.hist(exp_data)
# Out:
# (array([5.674e+03, 2.468e+03, 1.082e+03, 4.470e+02, 1.760e+02, 8.500e+01,
#         3.700e+01, 1.500e+01, 1.100e+01, 5.000e+00]),
#  array([4.48755089e-05, 8.42421863e-01, 1.68479885e+00, 2.52717584e+00,
#         3.36955282e+00, 4.21192981e+00, 5.05430680e+00, 5.89668379e+00,
#         6.73906077e+00, 7.58143776e+00, 8.42381475e+00]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.distplot(exp_data)
# Out:
# <Axes: ylabel='Density'>

# %%
normal_data=np.random.normal(size=1000000)
normal_data
# Out:
# array([ 1.16847665,  0.78172682, -2.06515723, ..., -0.6084831 ,
#         0.65081014, -0.12566378])

# %%
plt.hist(normal_data)
plt.show()

# %% [markdown]
# **Goal**:
# - Convert Exponential data to Normal data

# %% [markdown]
# **Log Transformation**
# - Log transformation means performing logarithm operations on original data
# - it is one of the approach to convert data to Normality
# - Log means natural logarithm base=e

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data
# Out:
# array([ 0.37755691, -0.82873353,  0.64277758, ..., -1.69298904,
#        -2.47888709, -2.97852675])

# %%
# we are hoping Log data might follows normality
# it might be possible or might not be possible
# we neeed to plot histogram again on Log data

# %%
plt.hist(log_data)
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(1,2,2).hist(log_data,bins=100,label='Log_data')
plt.legend()
plt.show()

# %% [markdown]
# **Square root Transformation:np.sqrt**

# %%
sqrt_data=np.sqrt(exp_data)
sqrt_data
# Out:
# array([1.20777335, 0.66075856, 1.37904164, ..., 0.42891585, 0.28954529,
#        0.22553873])

# %%
plt.hist(sqrt_data)
plt.show()

# %%
plt.figure(figsize=(14,3))
plt.subplot(1,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,bins=100,label='Sqrt_data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(2,2,2).hist(log_data,bins=100,label='Log_data')
plt.legend()
plt.subplot(2,2,3).hist(exp_data,bins=100,label='Exp_data')
plt.legend()
plt.subplot(2,2,4).hist(sqrt_data,bins=100,label='Sqrt_data')
plt.legend()
plt.show()

# %% [markdown]
# **Power Transformation**
# - power Transformation is used to Reduce the skewnes, so that distribution become symmetric
# - Under these two types are there
#   - Box-Cox Transfomation
#   - it applies to only postive data
#   - it has both Log transforamtion and square root transformation

# %% [markdown]
# **INCOMPLETE- ONE FORMULA WE SHOULD MISS**

# %%
**Your job is know about another method**
yeo-johnson========= formule tricky confused tomorrow i will
# Out:
#   Cell In[114], line 1
#     **Your job is know about another method**
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# - power transfromations are under sklearn package
# - sklearn
#   - preprocessing
#       - PowerTransfromation

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
plt.hist(trans_exp,bins=100)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='box-cox')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
plt.hist(trans_exp,bins=100)
plt.show()

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer(method='yeo-johnson')
exp_data=exp_data.reshape(-1,1)
trans_exp=pt.fit_transform(exp_data)
trans_sqrt=np.sqrt(trans_exp)
plt.hist(trans_exp,bins=100)
plt.show()
