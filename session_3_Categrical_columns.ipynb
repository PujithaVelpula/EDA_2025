# %%
class_names=visa_df['continent'].value_counts().keys()
class_fre=visa_df['continent'].value_counts().values
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(10,5))
plt.bar(class_names,
        class_fre,
        color=colors)
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('contient_BarChart')
plt.savefig('contient_BarChart.jpg')
plt.show()

# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
import pandas as pd
visa_df=pd.read_csv(r"C:\Users\purna\Documents\Naresh IT\assignments_ds\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# 1                         N             2412         2002
# 2                         Y            44444         2008
# 3                         N               98         1897
# 4                         N             1082         2005
# ...                     ...              ...          ...
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                     West         592.2029         Hour                  Y
# 1                Northeast       83425.6500         Year                  Y
# 2                     West      122996.8600         Year                  Y
# 3                     West       83434.0300         Year                  Y
# 4                    South      149907.3900         Year                  Y
# ...                    ...              ...          ...                ...
# 25475                South       77092.5700         Year                  Y
# 25476            Northeast      279174.7900         Year                  Y
# 25477                South      146298.8500         Year                  N
# 25478                 West       86154.7700         Year                  Y
# 25479              Midwest       70876.9100         Year                  Y
#
#       case_status
# 0          Denied
# 1       Certified
# 2          Denied
# 3          Denied
# 4       Certified
# ...           ...
# 25475   Certified
# 25476   Certified
# 25477   Certified
# 25478   Certified
# 25479   Certified
#
# [25480 rows x 12 columns]

# %%
visa_df['continent'].value_counts().keys()
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
visa_df['continent'].value_counts().values
# Out:
# array([16861,  3732,  3292,   852,   551,   192], dtype=int64)

# %%
import matplotlib.pyplot as plt
class_names=visa_df['continent'].value_counts().keys()
class_fre=visa_df['continent'].value_counts().values
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(10,5))
plt.bar(class_names,
        class_fre,
        color=colors)
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('contient_BarChart')
plt.savefig('contient_BarChart.jpg')
plt.show()

# %%
import matplotlib.pyplot as plt
class_counts = visa_df['continent'].value_counts()
class_names = class_counts.index
class_fre = class_counts.values
colors=['Red','Green','Yellow','Orange','Blue','Cyan']

plt.figure(figsize=(10, 5))
plt.bar(class_names, class_fre,color=colors)  
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('Continent Bar Chart')
plt.savefig('continent_BarChart.jpg')
plt.show()

# %%
visa_df.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
class_names=visa_df['case_status'].value_counts().keys()
class_fre=visa_df['case_status'].value_counts().values
colors=['Red','Green']
plt.figure(figsize=(10,5))
plt.bar(class_names,
        class_fre,
        color=colors)
plt.xlabel('Class Names')
plt.ylabel('Class Frequency')
plt.title('contient_BarChart')
plt.savefig('contient_BarChart.jpg')
plt.show()

# %%
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
for i in cat[1:]:
    class_names=visa_df[i].value_counts().keys()
    class_fre=visa_df[i].value_counts().values
    plt.figure(figsize=(10,5))
    plt.bar(class_names,
            class_fre,
           color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{i}_BarChart')
    plt.show()

# %% [markdown]
# **Subplots**

# %%
import matplotlib.pyplot as plt

plt.figure()  

plt.subplot(2, 2, 1)
plt.subplot(2, 2, 2)
plt.subplot(2, 2, 3)
plt.subplot(2, 2, 4)

plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[84], line 3
#       1 import matplotlib.pyplot as plt
#       2 for i in range(1,10):
# ----> 3     plt.Subplot(3,3,i)
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:641, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     639 else:
#     640     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#     643     raise ValueError('Width and height specified must be non-negative')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:576, in SubplotSpec._from_subplot_args(figure, args)
#     574     rows, cols, num = args
#     575 else:
# --> 576     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     578 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     579 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
import matplotlib.pyplot as plt

plt.figure() 

for i in range(1, 10):
    plt.subplot(3, 3, i) 
plt.show()

# %%
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(14,14))
for i in range(1,len(cat)):
    class_names=visa_df[cat[i]].value_counts().keys()
    class_fre=visa_df[cat[i]].value_counts().values
    plt.Subplot(3,3,i)
    plt.bar(class_names,class_fre,color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat[i]}_BarChart')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[94], line 6
#       4 class_names=visa_df[cat[i]].value_counts().keys()
#       5 class_fre=visa_df[cat[i]].value_counts().values
# ----> 6 plt.Subplot(3,3,i)
#       7 plt.bar(class_names,class_fre,color=colors)
#       8 plt.xlabel('Class Names')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:641, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     639 else:
#     640     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#     643     raise ValueError('Width and height specified must be non-negative')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:576, in SubplotSpec._from_subplot_args(figure, args)
#     574     rows, cols, num = args
#     575 else:
# --> 576     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     578 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     579 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(14,14))
for i in range(1,len(cat)):
    class_names=visa_df[cat[i]].value_counts().keys()
    class_fre=visa_df[cat[i]].value_counts().values
    plt.Subplot(3,3,i)
    plt.bar(class_names,class_fre,color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat[i]}_BarChart')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 6
#       4 class_names=visa_df[cat[i]].value_counts().keys()
#       5 class_fre=visa_df[cat[i]].value_counts().values
# ----> 6 plt.Subplot(3,3,i)
#       7 plt.bar(class_names,class_fre,color=colors)
#       8 plt.xlabel('Class Names')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:641, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     639 else:
#     640     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#     643     raise ValueError('Width and height specified must be non-negative')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:576, in SubplotSpec._from_subplot_args(figure, args)
#     574     rows, cols, num = args
#     575 else:
# --> 576     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     578 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     579 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
import matplotlib.pyplot as plt

plt.figure() 

for i in range(1, 10):
    plt.subplot(3, 3, i) 
plt.show()

# %%
colors=['Red','Green','Yellow','Orange','Blue','Cyan']
plt.figure(figsize=(14,14))
for i in range(1,len(cat)):
    class_names=visa_df[cat[i]].value_counts().keys()
    class_fre=visa_df[cat[i]].value_counts().values
    plt.Subplot(3,3,i)
    plt.bar(class_names,class_fre,color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat[i]}_BarChart')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 6
#       4 class_names=visa_df[cat[i]].value_counts().keys()
#       5 class_fre=visa_df[cat[i]].value_counts().values
# ----> 6 plt.Subplot(3,3,i)
#       7 plt.bar(class_names,class_fre,color=colors)
#       8 plt.xlabel('Class Names')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:641, in _AxesBase.__init__(self, fig, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, forward_navigation_events, *args, **kwargs)
#     639 else:
#     640     self._position = self._originalPosition = mtransforms.Bbox.unit()
# --> 641     subplotspec = SubplotSpec._from_subplot_args(fig, args)
#     642 if self._position.width < 0 or self._position.height < 0:
#     643     raise ValueError('Width and height specified must be non-negative')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\gridspec.py:576, in SubplotSpec._from_subplot_args(figure, args)
#     574     rows, cols, num = args
#     575 else:
# --> 576     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     578 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     579 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 14))  

for i in range(len(cat)):
    class_names = visa_df[cat[i]].value_counts().keys()
    class_fre = visa_df[cat[i]].value_counts().values
    
    plt.subplot(3, 3, i+1)  
    plt.bar(class_names, class_fre, color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat[i]}_BarChart')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 14))  # Proper figure call

for i in range(len(cat)):
    class_names = visa_df[cat[i]].value_counts().keys()
    class_fre = visa_df[cat[i]].value_counts().values
    
    plt.subplot(3, 3, i+1)  # Use lowercase 'subplot' and index starting from 1
    plt.bar(class_names, class_fre, color=colors)
    plt.xlabel('Class Names')
    plt.ylabel('Class Frequency')
    plt.title(f'{cat[i]}_BarChart')
    plt.xticks(rotation=45)  # Optional: rotate labels for readability

plt.tight_layout()
plt.show()
