# %% [markdown]
# 6/5/25

# %% [markdown]
# - under EDA
#    - Data analysis
#         - quick checks
#         - how to select the columns and data
#         - we understood the difference between df vs series vs values
#         - frequency tables
#         - bar chart
#         - pie chart
#         - histograms
#         - Distribution plots
#         - Ourtliers
#         - Deal with outliers
#         - bi veriate analysis
#         - multivariate analysis
#         - scatter plots
#         - correlation
#          - heatmaps
#   - Feature engineering
#         - Encoding
#         - Scaling
#         - Transformations
#         - Feature selection (how to select important features)

# %% [markdown]
# - encodeing because word can be converted into number because nlp neesds
# differnt columns has differnt units different range of values
# all the data under same scale scaling
# - data anaylsisis(till now)
# - encode == fe
# - scale the data
# - select the important features fs
# - model develpment

# %% [markdown]
# **Encoding**
# - convert categorical data to numerical data
# - ML algorithms develpoed by maths
# - maths need numbers
# - It is very important we need to convert categorical data to nuumerical
#    - map
#    - np.where
#    - LabelEncoder
#    - OneHotEncoder

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

visa_df=pd.read_csv(r"C:\Users\purna\Documents\Naresh IT\assignments_ds\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **map methods**

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['case_status'].unique()
# Out:
# array(['Denied', 'Certified'], dtype=object)

# %%
dict1={ 'Certified':0,'Denied':1}
dict1
# Out:
# {'Certified': 0, 'Denied': 1}

# %%
visa_df['case_status']=visa_df['case_status'].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['case_status_map']=visa_df['case_status'].map(dict1)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
dict2={'Asia':0,'North America':1}
dict2
# Out:
# {'Asia': 0, 'North America': 1}

# %%
visa_df['continent']=visa_df['continent'].map(dict2)

# %%
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01        0.0           High School                  N
# 1         EZYV02        0.0              Master's                  Y
# 2         EZYV03        0.0            Bachelor's                  N
# 3         EZYV04        0.0            Bachelor's                  N
# 4         EZYV05        NaN              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476        0.0            Bachelor's                  Y
# 25476  EZYV25477        0.0           High School                  Y
# 25477  EZYV25478        0.0              Master's                  Y
# 25478  EZYV25479        0.0              Master's                  Y
# 25479  EZYV25480        0.0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['continent_map']=visa_df['continent'].map(dict2)

# %%
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01        0.0           High School                  N
# 1         EZYV02        0.0              Master's                  Y
# 2         EZYV03        0.0            Bachelor's                  N
# 3         EZYV04        0.0            Bachelor's                  N
# 4         EZYV05        NaN              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476        0.0            Bachelor's                  Y
# 25476  EZYV25477        0.0           High School                  Y
# 25477  EZYV25478        0.0              Master's                  Y
# 25478  EZYV25479        0.0              Master's                  Y
# 25479  EZYV25480        0.0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
labels=visa_df['continent'].unique()
count=visa_df['continent'].nunique()
d={}
for i in range(len(labels)):
    #print(labels[i],i)
    d[labels[i]]=i
d
# Out:
# {'Asia': 0,
#  'Africa': 1,
#  'North America': 2,
#  'Europe': 3,
#  'South America': 4,
#  'Oceania': 5}

# %%
labels=visa_df['continent'].unique()
d={labels[i]:i for i in range(len(labels))}
visa_df['continent']=visa_df['continent'].map(d)
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df=pd.read_csv(r"C:\Users\purna\Documents\Naresh IT\assignments_ds\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
cat
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
for i in cat[1:]:
    labels = visa_df[i].unique()
    d = {labels[j]: j for j in range(len(labels))}
    visa_df[i] = visa_df[i].map(d)

# %%
visa_df
# Out:
#          case_id  continent education_of_employee has_job_experience  \
# 0         EZYV01          0           High School                  N
# 1         EZYV02          0              Master's                  Y
# 2         EZYV03          0            Bachelor's                  N
# 3         EZYV04          0            Bachelor's                  N
# 4         EZYV05          1              Master's                  Y
# ...          ...        ...                   ...                ...
# 25475  EZYV25476          0            Bachelor's                  Y
# 25476  EZYV25477          0           High School                  Y
# 25477  EZYV25478          0              Master's                  Y
# 25478  EZYV25479          0              Master's                  Y
# 25479  EZYV25480          0            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **Labels Encoder**

# %%
# step-1: Import the package
from sklearn.preprocessing import LabelEncoder
# step-2: save the packeg
le=LabelEncoder()
# step-3: fit and fit_transform

# fit means finding the some values
# transform means: transform apply those values
le.fit_transform(visa_df['case_status'])
# Out:
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
# step-1: Import the package
# step-2: save the packeg
# step-3: fit and fit_transform

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
import sklearn
sklearn
# Out:
# <module 'sklearn' from 'C:\\Users\\purna\\anaconda3\\Lib\\site-packages\\sklearn\\__init__.py'>

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
visa_df['case_status']=le.fit_transform(visa_df['case_status'])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in cat[1:]:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#          case_id  continent  education_of_employee  has_job_experience  \
# 0         EZYV01          0                      0                   0
# 1         EZYV02          0                      1                   1
# 2         EZYV03          0                      2                   0
# 3         EZYV04          0                      2                   0
# 4         EZYV05          1                      1                   1
# ...          ...        ...                    ...                 ...
# 25475  EZYV25476          0                      2                   1
# 25476  EZYV25477          0                      0                   1
# 25477  EZYV25478          0                      1                   1
# 25478  EZYV25479          0                      1                   1
# 25479  EZYV25480          0                      2                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %% [markdown]
# **OnehotEncoder**

# %%
visa_df=pd.read_csv(r"C:\Users\purna\Documents\Naresh IT\assignments_ds\Visadataset.csv")
cat=visa_df.select_dtypes(include='object').columns
num=visa_df.select_dtypes(exclude='object').columns
num
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df['case_status']
# Out:
# 0           Denied
# 1        Certified
# 2           Denied
# 3           Denied
# 4        Certified
#            ...
# 25475    Certified
# 25476    Certified
# 25477    Certified
# 25478    Certified
# 25479    Certified
# Name: case_status, Length: 25480, dtype: object

# %% [markdown]
# **pd.get_dummies**

# %%
pd.get_dummies(visa_df) # see the draw bacck
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage  case_id_EZYV01  \
# 0                14513         2007         592.2029            True
# 1                 2412         2002       83425.6500           False
# 2                44444         2008      122996.8600           False
# 3                   98         1897       83434.0300           False
# 4                 1082         2005      149907.3900           False
# ...                ...          ...              ...             ...
# 25475             2601         2008       77092.5700           False
# 25476             3274         2006      279174.7900           False
# 25477             1121         1910      146298.8500           False
# 25478             1918         1887       86154.7700           False
# 25479             3195         1960       70876.9100           False
#
#        case_id_EZYV02  case_id_EZYV03  case_id_EZYV04  case_id_EZYV05  \
# ...

# %%
pd.get_dummies(visa_df[cat[1:]])
# Out:
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                 False            True             False
# 1                 False            True             False
# 2                 False            True             False
# 3                 False            True             False
# 4                  True           False             False
# ...                 ...             ...               ...
# 25475             False            True             False
# 25476             False            True             False
# 25477             False            True             False
# 25478             False            True             False
# 25479             False            True             False
#
#        continent_North America  continent_Oceania  continent_South America  \
# 0                        False              False                    False
# 1                        False              False                    False
# ...

# %%
cols=cat[1:]
visa_df1=pd.get_dummies(visa_df,
                             columns=cols,
                             dtype=int)
visa_df1
# Out:
#          case_id  no_of_employees  yr_of_estab  prevailing_wage  \
# 0         EZYV01            14513         2007         592.2029
# 1         EZYV02             2412         2002       83425.6500
# 2         EZYV03            44444         2008      122996.8600
# 3         EZYV04               98         1897       83434.0300
# 4         EZYV05             1082         2005      149907.3900
# ...          ...              ...          ...              ...
# 25475  EZYV25476             2601         2008       77092.5700
# 25476  EZYV25477             3274         2006      279174.7900
# 25477  EZYV25478             1121         1910      146298.8500
# 25478  EZYV25479             1918         1887       86154.7700
# 25479  EZYV25480             3195         1960       70876.9100
#
#        continent_Africa  continent_Asia  continent_Europe  \
# 0                     0               1                 0
# 1                     0               1                 0
# ...
